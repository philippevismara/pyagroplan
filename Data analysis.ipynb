# %%
import pandas as pd

# %%
df_beds = pd.read_csv("data/beds_data_v2.csv", sep=";", decimal=",", false_values=["non"], true_values=["oui"])
df_beds
# Out:
#     planche  planche_contact  ombre_ete  ombre_hiver  proximite_atelier  \
# 0         1             2.00      False        False                  2
# 1         2             1.30      False        False                  2
# 2         3             2.40      False        False                  2
# 3         4             3.50      False        False                  2
# 4         5             4.60      False        False                  2
# ..      ...              ...        ...          ...                ...
# 75       76            75.77       True         True                  3
# 76       77            76.78       True         True                  3
# 77       78            77.79       True         True                  3
# 78       79            78.80       True         True                  3
# 79       80            79.00       True         True                  3
#
#     proximite_chemin jardins
# 0               True       A
# 1               True       A
# ...

# %%
df_beds.dtypes
# Out:
# planche                int64
# planche_contact      float64
# ombre_ete               bool
# ombre_hiver             bool
# proximite_atelier      int64
# proximite_chemin        bool
# jardins               object
# dtype: object

# %%
df_species_interactions = pd.read_csv("data/species_interactions_data.csv", sep=";", index_col="culture")
df_species_interactions
# Out:
#                   ail  arbres_fruitiers  artichaut  aubergine  autres  \
# culture
# ail                 0                 1         -1         -1       0
# arbres_fruitiers    1                 0          0          0       0
# artichaut          -1                 0          0          1       0
# aubergine          -1                 0          1          0       0
# autres              0                 0          0          0       0
# basilic             0                 0          0          1       0
# betterave           1                 0          0         -1       0
# blette              1                 1          0          0       0
# brocoli            -1                 0          1          0       0
# carotte             1                 1          0          1       0
# celeri              1                 0          0          0       0
# choux              -1                 0          1          0       0
# ...

# %%
df_species_interactions.dtypes
# Out:
# ail                 int64
# arbres_fruitiers    int64
# artichaut           int64
# aubergine           int64
# autres              int64
# basilic             int64
# betterave           int64
# blette              int64
# brocoli             int64
# carotte             int64
# celeri              int64
# choux               int64
# concombre           int64
# courges             int64
# courgette           int64
# engrais_vert        int64
# epinard             int64
# fenouil             int64
# feve                int64
# fraise              int64
# haricot             int64
# melon               int64
# navet               int64
# oignon              int64
# persil              int64
# petit_pois          int64
# poireau             int64
# poivron             int64
# pomme_de_terre      int64
# radis               int64
# rhubarbe            int64
# salade              int64
# tomates             int64
# dtype: object

# %%
df_crop_calendar = pd.read_csv("data/besoinsreelsPetC_v7_1an.csv", sep=";", index_col="culture")
df_crop_calendar
# Out:
#                           categorie  debut  fin  quantite  \
# culture
# Artichaut                 artichaut      7  268         7
# Fraise                       fraise      7  268         2
# Rhubarbe                   rhubarbe      7  268         2
# Ail                             ail     42   79         2
# Aubergine                 aubergine     19   45         1
# Betterave                 betterave     13   29         1
# Betterave                 betterave     34   47         1
# Betterave                 betterave     38   51         1
# Brocoli                     brocoli     33   40         1
# Brocoli                     brocoli     33   43         1
# Brocoli                     brocoli     33   56         1
# Butternut                   courges     22   36         2
# Carotte                     carotte     11   32         2
# Chou Cabus                    choux     33   45         1
# Chou Cabus                    choux     33   58         1
# ...

# %%
df_crops_metadata = df_crop_calendar.iloc[:, 5:15].drop_duplicates()
df_crops_metadata.to_csv("data/crops_metadata_v1.csv", sep=";")
df_crops_metadata
# Out:
#                             famille  delai_retour exigeante salissante  \
# culture
# Artichaut                asteracees             8       non        non
# Fraise                     rosacees             8       oui        non
# Rhubarbe               polygonacees             8       non        non
# Ail                        aliacees             4       oui        oui
# Aubergine                solanacees             4       oui        non
# Betterave            chenopodiacees             2       non        oui
# Brocoli                brassicacees             4       oui        non
# Butternut             cucurbitacees             4       oui        non
# Carotte                    apiacees             2       non        oui
# Chou-rave fenouil          apiacees             2       non        oui
# Concombre                solanacees             4       oui        non
# Courgette             cucurbitacees             4       oui        non
# ...

# %%
df_crop_calendar.drop(columns=df_crop_calendar.columns[5:], inplace=True)
df_crop_calendar.to_csv("data/crop_calendar_1an_v7.csv", sep=";")
df_crop_calendar
# Out:
#                           categorie  debut  fin  quantite  \
# culture
# Artichaut                 artichaut      7  268         7
# Fraise                       fraise      7  268         2
# Rhubarbe                   rhubarbe      7  268         2
# Ail                             ail     42   79         2
# Aubergine                 aubergine     19   45         1
# Betterave                 betterave     13   29         1
# Betterave                 betterave     34   47         1
# Betterave                 betterave     38   51         1
# Brocoli                     brocoli     33   40         1
# Brocoli                     brocoli     33   43         1
# Brocoli                     brocoli     33   56         1
# Butternut                   courges     22   36         2
# Carotte                     carotte     11   32         2
# Chou Cabus                    choux     33   45         1
# Chou Cabus                    choux     33   58         1
# ...

# %%
df_crop_calendar = pd.read_csv("data/besoinsreelsPetC_v8_1an_v1.csv", sep=";", index_col="culture")
df_crop_calendar
# Out:
#                         categorie  debut  fin  quantite  \
# culture
# Ail                           ail    144  164         2
# Aubergine               aubergine    122  147         1
# Betterave               betterave    117  130         1
# Betterave               betterave    139  151         1
# Betterave               betterave    141  153         1
# Brocoli                   brocoli    137  147         1
# Brocoli                   brocoli    137  144         1
# Brocoli                   brocoli    137  158         1
# Butternut                 courges    125  141         2
# Carotte                   carotte    116  132         2
# Chou Cabus                  choux    136  148         1
# Chou Cabus                  choux    136  157         1
# Chou de milan               choux    136  151         1
# chou frise                  choux    117  152         1
# Chou Romanesco              choux    136  150         1
# Chou-fleur                  choux    136  147         1
# ...

# %%
df_crops_metadata = df_crop_calendar.iloc[:, 5:15].drop_duplicates()
df_crops_metadata.to_csv("data/crops_metadata_v2.csv", sep=";")
df_crops_metadata
# Out:
#                           famille  delai_retour exigeante salissante  \
# culture
# Ail                      aliacees             4       oui        oui
# Aubergine              solanacees             4       oui        non
# Betterave          chenopodiacees             2       non        oui
# Brocoli              brassicacees             4       oui        non
# Butternut           cucurbitacees             4       oui        non
# Carotte                  apiacees             2       non        oui
# Chou-rave            brassicacees             2       non        oui
# Concombre           cucurbitacees             4       oui        non
# Courgette           cucurbitacees             4       oui        non
# Echalotte                aliacees             4       oui        oui
# Engrais vert ete     engrais_vert             8       non        non
# epinard            chenopodiacees             2       non        non
# ...

# %%
df_crop_calendar.drop(columns=df_crop_calendar.columns[5:], inplace=True)
df_crop_calendar.to_csv("data/crop_calendar_1an_v8_v1.csv", sep=";")
df_crop_calendar
# Out:
#                         categorie  debut  fin  quantite  \
# culture
# Ail                           ail    144  164         2
# Aubergine               aubergine    122  147         1
# Betterave               betterave    117  130         1
# Betterave               betterave    139  151         1
# Betterave               betterave    141  153         1
# Brocoli                   brocoli    137  147         1
# Brocoli                   brocoli    137  144         1
# Brocoli                   brocoli    137  158         1
# Butternut                 courges    125  141         2
# Carotte                   carotte    116  132         2
# Chou Cabus                  choux    136  148         1
# Chou Cabus                  choux    136  157         1
# Chou de milan               choux    136  151         1
# chou frise                  choux    117  152         1
# Chou Romanesco              choux    136  150         1
# Chou-fleur                  choux    136  147         1
# ...

# %%
df_crop_calendar = pd.read_csv("data/besoinsreelsPetC_v8_1an_v2.csv", sep=";", index_col="culture")
df_crop_calendar
# Out:
#                         categorie  debut  fin  quantite  \
# culture
# Ail                           ail    144  164         2
# Aubergine               aubergine    122  147         1
# Betterave               betterave    117  130         1
# Betterave               betterave    139  151         1
# Betterave               betterave    141  153         1
# Brocoli                   brocoli    137  147         1
# Brocoli                   brocoli    137  144         1
# Brocoli                   brocoli    137  158         1
# Butternut                 courges    125  141         2
# Carotte                   carotte    116  132         2
# Chou Cabus                  choux    136  148         1
# Chou Cabus                  choux    136  157         1
# Chou de milan               choux    136  151         1
# chou frise                  choux    117  152         1
# Chou Romanesco              choux    136  150         1
# Chou-fleur                  choux    136  147         1
# ...

# %%
df_crops_metadata = df_crop_calendar.iloc[:, 5:15].drop_duplicates()
df_crops_metadata.to_csv("data/crops_metadata_v3.csv", sep=";")
df_crops_metadata
# Out:
#                           famille  delai_retour exigeante salissante  \
# culture
# Ail                      aliacees             4       oui        oui
# Aubergine              solanacees             4       oui        non
# Betterave          chenopodiacees             2       non        oui
# Brocoli              brassicacees             4       oui        non
# Butternut           cucurbitacees             4       oui        non
# Carotte                  apiacees             2       non        oui
# Chou-rave            brassicacees             2       non        oui
# Concombre           cucurbitacees             4       oui        non
# Courgette           cucurbitacees             4       oui        non
# Echalotte                aliacees             4       oui        oui
# Engrais vert ete     engrais_vert             8       non        non
# epinard            chenopodiacees             2       non        non
# ...

# %%
df_crop_calendar.drop(columns=df_crop_calendar.columns[5:], inplace=True)
df_crop_calendar.to_csv("data/crop_calendar_1an_v8_v2.csv", sep=";")
df_crop_calendar
# Out:
#                         categorie  debut  fin  quantite  \
# culture
# Ail                           ail    144  164         2
# Aubergine               aubergine    122  147         1
# Betterave               betterave    117  130         1
# Betterave               betterave    139  151         1
# Betterave               betterave    141  153         1
# Brocoli                   brocoli    137  147         1
# Brocoli                   brocoli    137  144         1
# Brocoli                   brocoli    137  158         1
# Butternut                 courges    125  141         2
# Carotte                   carotte    116  132         2
# Chou Cabus                  choux    136  148         1
# Chou Cabus                  choux    136  157         1
# Chou de milan               choux    136  151         1
# chou frise                  choux    117  152         1
# Chou Romanesco              choux    136  150         1
# Chou-fleur                  choux    136  147         1
# ...
